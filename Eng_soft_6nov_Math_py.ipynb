# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusmatiassilva2-crypto/tecnicas-de-programac-o/blob/main/Eng_soft_6nov_Math_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Operadores

# %%
1 * 2**3
# Out:
# 8

# %%
1 * 23/7
# Out:
# 3.2857142857142856

# %%
1 * 23%7
# Out:
# 2

# %%
5 + 5 / 5 * 5
# Out:
# 10.0

# %%
4**(4/2) +7
# Out:
# 23.0

# %%
a=int (input("informe o numero: "))
b=int (input("informe o numero: "))
print (" O resultado e ", a+b)
# Out:
# informe o numero: 78
# informe o numero: 75
#  O resultado e  153

# %%
#2
nota1 = 5
nota2 = 7
media_aritmetca = (nota1 + nota2)/2

print(media_aritmetca)
# Out:
# 6.0

# %%
#3
print('Digite seu nome ')
nome_usuario = input()
print(f'Ola {nome_usuario}')
# Out:
# Digite seu nome

# %%
#4
print ('Digite seu nome ')
nome_usuario = input()

print ('Digite seu ano de nascimento (AAAA):')
ano_nascimento = input()
print(f'{nome_usuario} nasceu em {ano_nascimento}!')
# Out:
# Digite seu nome
# matheus
# Digite seu ano de nascimento (AAAA):
# 01/09/2008
# matheus nasceu em 01/09/2008!

# %%
#5
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))

print(f"Olá, {nome}! Você tem {idade} anos?")

ano_atual = 2025
ano_nascimento = ano_atual - idade
print(f"Você nasceu em {ano_nascimento}.")

print(nome * idade)

# %%
#6
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))

peso1 = 2
peso2 = 3
peso3 = 5

media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)

print(f"A média ponderada é: {media_ponderada:.2f}")

# %%
#7

print("Vamos calcular a Média Ponderada de três notas.")
nota1 = float(input("Digite a primeira nota: "))
peso1 = float(input("Digite o peso da primeira nota: "))

nota2 = float(input("Digite a segunda nota: "))
peso2 = float(input("Digite o peso da segunda nota: "))

nota3 = float(input("Digite a terceira nota: "))
peso3 = float(input("Digite o peso da terceira nota: "))

soma_produtos = (nota1 * peso1) + (nota2 * peso2) + (nota3 * peso3)
soma_pesos = peso1 + peso2 + peso3

if soma_pesos > 0:
    media_ponderada = soma_produtos / soma_pesos

    print("\n--- Resultado ---")
    print(f"Soma dos Produtos (Notas * Pesos): {soma_produtos:.2f}")
    print(f"Soma dos Pesos: {soma_pesos:.2f}")
    print(f"A Média Ponderada é: {media_ponderada:.2f}")
else:
    print("\nAtenção: A soma dos pesos não pode ser zero. O cálculo não pôde ser realizado.")

# %%
#8
numero_str = input("Digite um número inteiro: ")

soma_digitos = 0

for digito_char in numero_str:
    if digito_char.isdigit():

        soma_digitos += int(digito_char)

print(f"\nO número digitado foi: {numero_str}")
print(f"A soma dos seus dígitos é: {soma_digitos}")

# %%
#9
palavra = input("Digite uma palavra: ")

palavra_invertida = palavra[::-1]

print("\n--- Resultado ---")
print(f"A palavra original é: {palavra}")
print(f"A palavra invertida é: {palavra_invertida}")
