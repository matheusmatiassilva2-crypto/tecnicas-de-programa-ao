# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusmatiassilva2-crypto/tecnicas-de-programac-o/blob/main/Quest%C3%B5es_de_Codifica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1
num1 = int(input("Digite o primeiro número inteiro: "))

num2 = int(input("Digite o segundo número inteiro: "))



soma = num1 + num2



print("A soma dos dois números é:", soma)

# %%
#2
p1 = float(input("Digite a nota da P1: "))

p2 = float(input("Digite a nota da P2: "))



media = (p1 + p2) / 2



print("A média aritmética é:", media)

# %%
#3
nome_pessoa = input("Digite o seu nome: ")



print("Olá,", nome_pessoa + "!")

# %%
#4
nome_usuario = input("Digite o seu nome: ")

ano_nascimento = input("Digite o seu ano de nascimento (formato AAAA): ")



print(nome_usuario, "nasceu em", ano_nascimento + "!")

# %%
#5
nome = input("Digite o seu nome: ")

idade = int(input("Digite a sua idade: "))



ano_atual = 2025

ano_nascimento = ano_atual - idade



print(f"Olá, {nome}! Você tem {idade} anos?")

print(f"Você nasceu em {ano_nascimento}.")

print(nome * idade)

# %%
#6
nota1 = float(input("Digite a primeira nota: "))

nota2 = float(input("Digite a segunda nota: "))

nota3 = float(input("Digite a terceira nota: "))



media = (nota1 + nota2 + nota3) / 3



print("A média aritmética é:", media)

# %%
#7
nota1 = float(input("Digite a primeira nota: "))

peso1 = float(input("Digite o peso da primeira nota: "))



nota2 = float(input("Digite a segunda nota: "))

peso2 = float(input("Digite o peso da segunda nota: "))



nota3 = float(input("Digite a terceira nota: "))

peso3 = float(input("Digite o peso da terceira nota: "))



media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)



print("A média ponderada é:", media_ponderada)

# %%
#8
numero = input("Digite um número: ")



soma = 0

for digito in numero:

  soma += int(digito)



print("A soma dos dígitos é:", soma)

# %%
#9
palavra = input("Digite uma palavra: ")



invertida = palavra[::-1]



print("Palavra invertida:", invertida)
